# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("Train.xlsx")
df
# Out:
#       PropertyID  Borough State  Surroundings                 Address  \
# 0        PR11101        1    NY      BATHGATE      1473 CROTONA PLACE
# 1        PR11102        1    NY      BATHGATE            453 EAST 181
# 2        PR11103        1    NY      BATHGATE     511 EAST 171 STREET
# 3        PR11104        1    NY      BATHGATE   547 CLAREMONT PARKWAY
# 4        PR11105        1    NY      BATHGATE  2063 WASHINGTON AVENUE
# ...          ...      ...   ...           ...                     ...
# 16805    PR27906        4    NY  CIVIC CENTER           30 PARK PLACE
# 16806    PR27907        4    NY  CIVIC CENTER       56 LEONARD STREET
# 16807    PR27908        4    NY  CIVIC CENTER       56 LEONARD STREET
# 16808    PR27909        4    NY       TRIBECA    250 SOUTH END AVENUE
# 16809    PR27910        4    NY  HARLEM-UPPER     415 WEST 150 STREET
#
#        ZipCode  Block   Lot                  BldgClassCategory  \
# 0        10456   2927   127            02 TWO FAMILY DWELLINGS
# 1        10457   3037   110          03 THREE FAMILY DWELLINGS
# 2        10457   2912   155            02 TWO FAMILY DWELLINGS
# 3        10457   2929   134            02 TWO FAMILY DWELLINGS
# 4        10457   3036   140            02 TWO FAMILY DWELLINGS
# ...        ...    ...   ...                                ...
# 16805    10007    123  1213    13 CONDOS - ELEVATOR APARTMENTS
# 16806    10013    176  1054    13 CONDOS - ELEVATOR APARTMENTS
# 16807    10013    176  1102    13 CONDOS - ELEVATOR APARTMENTS
# 16808    10280     16  2249    13 CONDOS - ELEVATOR APARTMENTS
# 16809    10031   2065    22  08  RENTALS - ELEVATOR APARTMENTS
#
#        NoOfResidentialUnits  NoOfCommercialUnits  TotalNoOfUnits  \
# 0                         2                    0               2
# 1                         3                    0               3
# 2                         2                    0               2
# 3                         2                    0               2
# 4                         2                    0               2
# ...                     ...                  ...             ...
# 16805                     1                    0               1
# 16806                     1                    0               1
# 16807                     1                    0               1
# 16808                     1                    0               1
# 16809                    16                    1              17
#
#        LandAreaInSqFt  GrossAreaInSqFt  YearOfConstruction  \
# 0                1900             2394                1990
# 1                1687             3037                2002
# 2                2000             2400                1989
# 3                2356             2394                1991
# 4                3346             2308                1993
# ...               ...              ...                 ...
# 16805           29715             2803                2004
# 16806           12518             2252                2003
# 16807           12518             2177                2003
# 16808           12644              594                1981
# 16809            4996            29529                2007
#
#        TaxClass_AtEvaluationTime BldgClass_AtEvaluationTime DateOfEvaluation  \
# 0                              1                         B1       2014-05-30
# 1                              1                         C0       2014-09-13
# 2                              1                         B1       2014-09-28
# 3                              1                         B1       2014-06-05
# 4                              1                         B1       2015-02-07
# ...                          ...                        ...              ...
# 16805                          2                         R4       2014-11-30
# 16806                          2                         R4       2014-12-19
# 16807                          2                         R4       2014-11-16
# 16808                          2                         R4       2014-09-17
# 16809                          2                         D7       2013-03-22
#
#        PropertyEvaluationvalue
# 0                       540000
# 1                       750000
# 2                       470000
# 3                       570000
# 4                       640000
# ...                        ...
# 16805                  8454562
# 16806                  6250000
# 16807                  7150000
# 16808                   550000
# 16809                  5000000
#
# [16810 rows x 19 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16810 entries, 0 to 16809
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PropertyID                  16810 non-null  object
#  1   Borough                     16810 non-null  int64
#  2   State                       16810 non-null  object
#  3   Surroundings                16810 non-null  object
#  4   Address                     16810 non-null  object
#  5   ZipCode                     16810 non-null  int64
#  6   Block                       16810 non-null  int64
#  7   Lot                         16810 non-null  int64
#  8   BldgClassCategory           16810 non-null  object
#  9   NoOfResidentialUnits        16810 non-null  int64
#  10  NoOfCommercialUnits         16810 non-null  int64
#  11  TotalNoOfUnits              16810 non-null  int64
#  12  LandAreaInSqFt              16810 non-null  int64
#  13  GrossAreaInSqFt             16810 non-null  int64
#  14  YearOfConstruction          16810 non-null  int64
#  15  TaxClass_AtEvaluationTime   16810 non-null  int64
#  16  BldgClass_AtEvaluationTime  16810 non-null  object
#  17  DateOfEvaluation            16810 non-null  datetime64[ns]
#  18  PropertyEvaluationvalue     16810 non-null  int64
# dtypes: datetime64[ns](1), int64(12), object(6)
# memory usage: 2.4+ MB

# %%
df.describe()
# Out:
#             Borough       ZipCode         Block           Lot  \
# count  16810.000000  16810.000000  16810.000000  16810.000000
# mean       3.439143  10871.027543   5428.122308    266.327722
# std        1.398950    522.996869   3710.031921    542.420132
# min        1.000000  10001.000000      6.000000      1.000000
# 25%        2.000000  10312.000000   2401.250000     25.000000
# 50%        3.000000  11207.000000   5050.000000     52.000000
# 75%        5.000000  11364.000000   7376.750000    138.000000
# max        5.000000  11694.000000  16314.000000   5323.000000
#
#        NoOfResidentialUnits  NoOfCommercialUnits  TotalNoOfUnits  \
# count          16810.000000         16810.000000    16810.000000
# mean               1.862225             0.137775        2.000000
# std                8.027805             2.185857        8.472771
# min                0.000000             0.000000        1.000000
# 25%                1.000000             0.000000        1.000000
# 50%                1.000000             0.000000        1.000000
# 75%                2.000000             0.000000        2.000000
# max              437.000000           252.000000      437.000000
#
#        LandAreaInSqFt  GrossAreaInSqFt  YearOfConstruction  \
# count    1.681000e+04     1.681000e+04        16810.000000
# mean     1.092492e+04     3.612157e+03         1973.982867
# std      5.837620e+04     1.627378e+04           23.632595
# min      1.000000e+00     1.000000e+00         1941.000000
# 25%      2.100000e+03     1.224000e+03         1951.000000
# 50%      3.200000e+03     1.750000e+03         1968.000000
# 75%      5.000000e+03     2.449750e+03         1998.000000
# max      5.612000e+06     1.172005e+06         2012.000000
#
#        TaxClass_AtEvaluationTime  PropertyEvaluationvalue
# count               16810.000000             1.681000e+04
# mean                    1.289530             8.084101e+05
# std                     0.713779             8.978317e+05
# min                     1.000000             1.000440e+05
# 25%                     1.000000             4.250000e+05
# 50%                     1.000000             5.900000e+05
# 75%                     1.000000             8.450000e+05
# max                     4.000000             9.935000e+06

# %%
df.drop_duplicates(keep='first', inplace=True)

# %%
print(df.shape)
# Out:
# (16810, 19)

# %%
df.isna().sum()
# Out:
# PropertyID                    0
# Borough                       0
# State                         0
# Surroundings                  0
# Address                       0
# ZipCode                       0
# Block                         0
# Lot                           0
# BldgClassCategory             0
# NoOfResidentialUnits          0
# NoOfCommercialUnits           0
# TotalNoOfUnits                0
# LandAreaInSqFt                0
# GrossAreaInSqFt               0
# YearOfConstruction            0
# TaxClass_AtEvaluationTime     0
# BldgClass_AtEvaluationTime    0
# DateOfEvaluation              0
# PropertyEvaluationvalue       0
# dtype: int64

# %% [markdown]
# ## Ananyze Each Feature

# %%
for i in df.columns:
    if df[i].dtype == "object":
        print(i + " has " + str(len(df[i].unique())) + " unique values")
# Out:
# PropertyID has 16810 unique values
# State has 1 unique values
# Surroundings has 243 unique values
# Address has 15219 unique values
# BldgClassCategory has 52 unique values
# BldgClass_AtEvaluationTime has 101 unique values

# %%
for i in df.columns[0:8]:
    if df[i].dtype != "object":
        print(i + " has " + str(len(df[i].unique())) + " unique values")
# Out:
# Borough has 5 unique values
# ZipCode has 174 unique values
# Block has 6405 unique values
# Lot has 1299 unique values

# %%
for i in df.columns[9:14]:
    plt.figure(figsize = (20,3))
    sns.boxplot(df[i], showfliers = False, orient="h")
    plt.title(i)

# %%
by_comm_unit = df.groupby('NoOfCommercialUnits').count()
plt.figure(figsize = (20,10))
sns.barplot(data=by_comm_unit, x=by_comm_unit.index, y=by_comm_unit['PropertyID'])
plt.title("NoOfCommercialUnits")
# Out:
# Text(0.5, 1.0, 'NoOfCommercialUnits')

# %%
by_construction_year = df.groupby("YearOfConstruction").count()
plt.figure(figsize = (20,5))
sns.barplot(data=by_construction_year,x=by_construction_year.index,y=by_construction_year['PropertyID'])
plt.title("YearOfConstruction")
plt.xticks(rotation=45);

# %%
import datetime
df["DateOfEvaluation"] = pd.to_datetime(df["DateOfEvaluation"])

# %%
df['EvaluationYear'] = df["DateOfEvaluation"].dt.year

# %%
df['EvaluationMonth'] = df["DateOfEvaluation"].dt.month

# %%
df['EvaluationDay'] = df["DateOfEvaluation"].dt.day

# %%
df.drop("DateOfEvaluation", axis=1, inplace=True)

# %%
df['EvaluationYear'].unique()
# Out:
# array([2014, 2015, 2012, 2013], dtype=int64)

# %%
plt.figure(figsize = (20,5))
sns.boxplot(df["PropertyEvaluationvalue"], showfliers = False, orient='h')
plt.title("PropertyEvaluationvalue")
plt.ticklabel_format(useOffset=False,style="plain", axis="x")

# %% [markdown]
# ## EDA

# %%
by_borough = df.groupby('Borough').count()
plt.figure(figsize=(20,10))
sns.barplot(data=by_borough,x=by_borough.index,y=by_borough['PropertyID'])
plt.title("Count by Borough")
plt.grid()

# %%
count_by_zip = df.groupby("ZipCode").count()["PropertyID"].sort_values(ascending=False)
count_by_zip
# Out:
# ZipCode
# 10312    1002
# 10314     965
# 10306     580
# 10309     527
# 10305     383
#          ...
# 10033       2
# 10040       2
# 11430       1
# 10803       1
# 10031       1
# Name: PropertyID, Length: 174, dtype: int64

# %%
count_by_block = df.groupby("Block").count()["PropertyID"].sort_values(ascending=False)
count_by_block
# Out:
# Block
# 1009     140
# 5066      57
# 2450      57
# 4995      49
# 1129      47
#         ...
# 5403       1
# 5423       1
# 5426       1
# 5430       1
# 16314      1
# Name: PropertyID, Length: 6405, dtype: int64

# %%
count_by_building_type = df.groupby("BldgClassCategory").count()
plt.figure(figsize=(20,15))
sns.barplot(data=count_by_building_type,
            x=count_by_building_type['PropertyID'],
            y=count_by_building_type.index,
            order=count_by_building_type.sort_values('PropertyID', ascending=False).index,
            orient='h')
plt.title("Count by Building Category")
plt.xlabel("Count")
plt.ylabel("Building Class")
plt.grid()

# %%
count_by_surroundings = df.groupby("Surroundings").count()
plt.figure(figsize=(20,40))
sns.barplot(data=count_by_surroundings,
            x=count_by_surroundings['PropertyID'],
            y=count_by_surroundings.index,
            order=count_by_surroundings.sort_values('PropertyID', ascending=False).index,
            orient='h')
plt.title("Count by Sorroundings")
plt.xlabel("Count")
plt.ylabel("Surroundings")
plt.grid()

# %%
count_number_residential_units = df.groupby("NoOfResidentialUnits").count()["PropertyID"].sort_values(ascending=False)
count_number_residential_units
# Out:
# NoOfResidentialUnits
# 1      9850
# 2      4705
# 3      1159
# 0       802
# 4        88
#        ...
# 70        1
# 71        1
# 72        1
# 74        1
# 437       1
# Name: PropertyID, Length: 70, dtype: int64

# %%
count_number_commercial_units = df.groupby("NoOfCommercialUnits").count()["PropertyID"].sort_values(ascending=False)
count_number_commercial_units
# Out:
# NoOfCommercialUnits
# 0      15790
# 1        647
# 2        261
# 3         36
# 4         20
# 6         12
# 29        11
# 5         10
# 8          6
# 7          4
# 12         3
# 10         3
# 11         2
# 14         1
# 15         1
# 26         1
# 47         1
# 252        1
# Name: PropertyID, dtype: int64

# %%
count_number_total_units = df.groupby("TotalNoOfUnits").count()["PropertyID"].sort_values(ascending=False)
count_number_total_units.head(25)
# Out:
# TotalNoOfUnits
# 1      10283
# 2       4909
# 3       1231
# 4        118
# 6         45
# 5         41
# 8         28
# 7         16
# 84         9
# 10         9
# 11         7
# 9          7
# 12         5
# 16         5
# 14         4
# 39         4
# 124        4
# 20         4
# 21         4
# 30         3
# 50         3
# 37         3
# 113        3
# 38         3
# 156        2
# Name: PropertyID, dtype: int64

# %%
upper_lim_gross_sqft = df["GrossAreaInSqFt"].quantile(.95)
lower_lim_gross_sqft = df["GrossAreaInSqFt"].quantile(.025)
sqft_distribution = df[(df["GrossAreaInSqFt"] > lower_lim_gross_sqft) & (df["GrossAreaInSqFt"] < upper_lim_gross_sqft)]

plt.figure(figsize=(20,5))
sns.histplot(sqft_distribution['GrossAreaInSqFt'], kde=True)
plt.ticklabel_format(useOffset=False,style="plain", axis="x")

# %%
upper_lim_land_sqft = df["LandAreaInSqFt"].quantile(.95)
lower_lim_land_sqft = df["LandAreaInSqFt"].quantile(.025)
sqft_distribution = df[(df["LandAreaInSqFt"] > lower_lim_land_sqft) & (df["LandAreaInSqFt"] < upper_lim_land_sqft)]

plt.figure(figsize=(20,5))
sns.histplot(sqft_distribution['LandAreaInSqFt'], kde=True)
plt.ticklabel_format(useOffset=False,style="plain", axis="x")

# %%
plt.figure(figsize=(20,5))
sns.histplot(df["TaxClass_AtEvaluationTime"])
plt.title("Count by Tax Class")
plt.grid()

# %%
plt.figure(figsize=(20,10))
sns.histplot(df['PropertyEvaluationvalue'], kde=True, bins=100)
plt.ticklabel_format(useOffset=False,style="plain", axis="x")

# %%
plt.figure(figsize=(20,5))
sns.boxplot(df['PropertyEvaluationvalue'], orient='h')
plt.ticklabel_format(useOffset=False,style="plain", axis="x")

# %% [markdown]
# ## Analyze Correlation

# %%
plt.figure(figsize=(20,10))
mask = np.triu(np.ones_like(df.corr(), dtype=bool))
sns.heatmap(df.corr(), mask=mask, annot=True)
# Out:
# C:\Users\Marcos Verdi\AppData\Local\Temp\ipykernel_16048\2231182186.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mask = np.triu(np.ones_like(df.corr(), dtype=bool))
# C:\Users\Marcos Verdi\AppData\Local\Temp\ipykernel_16048\2231182186.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), mask=mask, annot=True)
# <Axes: >

# %%
corr = df.corr()
plt.figure(figsize=(20,5))
corr['PropertyEvaluationvalue'].sort_values(ascending=False)[1:].plot(kind="bar")
# Out:
# C:\Users\Marcos Verdi\AppData\Local\Temp\ipykernel_16048\1163535556.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
# <Axes: >

# %% [markdown]
# It seems that we can drop a few features to start such as PropertyID, State, Block, Address to start with

# %%
test1 = df.copy()

# %%
test1.drop(['PropertyID', 'State', 'Block', 'Address'], axis=1, inplace=True)

# %% [markdown]
# ## Encode Categorical Values and Split Data for the Model

# %%
test1.head(5)
# Out:
#    Borough  ZipCode  Lot  NoOfResidentialUnits  NoOfCommercialUnits  \
# 0        1    10456  127                     2                    0
# 1        1    10457  110                     3                    0
# 2        1    10457  155                     2                    0
# 3        1    10457  134                     2                    0
# 4        1    10457  140                     2                    0
#
#    TotalNoOfUnits  LandAreaInSqFt  GrossAreaInSqFt  YearOfConstruction  \
# 0               2            1900             2394                1990
# 1               3            1687             3037                2002
# 2               2            2000             2400                1989
# 3               2            2356             2394                1991
# 4               2            3346             2308                1993
#
#    TaxClass_AtEvaluationTime  PropertyEvaluationvalue  EvaluationYear  \
# 0                          1                   540000            2014
# 1                          1                   750000            2014
# 2                          1                   470000            2014
# 3                          1                   570000            2014
# 4                          1                   640000            2015
#
#    EvaluationMonth  EvaluationDay
# 0                5             30
# 1                9             13
# 2                9             28
# 3                6              5
# 4                2              7

# %%
cols_to_encode = ['Surroundings','BldgClassCategory','BldgClass_AtEvaluationTime']

for col in cols_to_encode:
    temp = pd.get_dummies(col,drop_first=True)
    test1.drop(col,axis=1,inplace=True)
    test1 = pd.concat([test1,temp],axis=1)

# %%
test1
# Out:
#        Borough  ZipCode   Lot  NoOfResidentialUnits  NoOfCommercialUnits  \
# 0            1    10456   127                     2                    0
# 1            1    10457   110                     3                    0
# 2            1    10457   155                     2                    0
# 3            1    10457   134                     2                    0
# 4            1    10457   140                     2                    0
# ...        ...      ...   ...                   ...                  ...
# 16805        4    10007  1213                     1                    0
# 16806        4    10013  1054                     1                    0
# 16807        4    10013  1102                     1                    0
# 16808        4    10280  2249                     1                    0
# 16809        4    10031    22                    16                    1
#
#        TotalNoOfUnits  LandAreaInSqFt  GrossAreaInSqFt  YearOfConstruction  \
# 0                   2            1900             2394                1990
# 1                   3            1687             3037                2002
# 2                   2            2000             2400                1989
# 3                   2            2356             2394                1991
# 4                   2            3346             2308                1993
# ...               ...             ...              ...                 ...
# 16805               1           29715             2803                2004
# 16806               1           12518             2252                2003
# 16807               1           12518             2177                2003
# 16808               1           12644              594                1981
# 16809              17            4996            29529                2007
#
#        TaxClass_AtEvaluationTime  PropertyEvaluationvalue  EvaluationYear  \
# 0                              1                   540000            2014
# 1                              1                   750000            2014
# 2                              1                   470000            2014
# 3                              1                   570000            2014
# 4                              1                   640000            2015
# ...                          ...                      ...             ...
# 16805                          2                  8454562            2014
# 16806                          2                  6250000            2014
# 16807                          2                  7150000            2014
# 16808                          2                   550000            2014
# 16809                          2                  5000000            2013
#
#        EvaluationMonth  EvaluationDay
# 0                    5             30
# 1                    9             13
# 2                    9             28
# 3                    6              5
# 4                    2              7
# ...                ...            ...
# 16805               11             30
# 16806               12             19
# 16807               11             16
# 16808                9             17
# 16809                3             22
#
# [16810 rows x 14 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
cols_to_label = ['ZipCode','Lot','YearOfConstruction']

for col in cols_to_label:
    test1[col] = le.fit_transform(test1[col])

# %%
test1.head(5)
# Out:
#    Borough  ZipCode  Lot  NoOfResidentialUnits  NoOfCommercialUnits  \
# 0        1       55  126                     2                    0
# 1        1       56  109                     3                    0
# 2        1       56  154                     2                    0
# 3        1       56  133                     2                    0
# 4        1       56  139                     2                    0
#
#    TotalNoOfUnits  LandAreaInSqFt  GrossAreaInSqFt  YearOfConstruction  \
# 0               2            1900             2394                  49
# 1               3            1687             3037                  61
# 2               2            2000             2400                  48
# 3               2            2356             2394                  50
# 4               2            3346             2308                  52
#
#    TaxClass_AtEvaluationTime  PropertyEvaluationvalue  EvaluationYear  \
# 0                          1                   540000            2014
# 1                          1                   750000            2014
# 2                          1                   470000            2014
# 3                          1                   570000            2014
# 4                          1                   640000            2015
#
#    EvaluationMonth  EvaluationDay
# 0                5             30
# 1                9             13
# 2                9             28
# 3                6              5
# 4                2              7

# %% [markdown]
# Create First Model

# %%
X = test1.drop('PropertyEvaluationvalue',axis=1)
y = test1['PropertyEvaluationvalue']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test  = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
lin_rg = LinearRegression()
rdg_rg = Ridge()
lss_rg = Lasso()
dt_rg = DecisionTreeRegressor()
rf_rg = RandomForestRegressor()

# %%
regressors = [lin_rg,rdg_rg,lss_rg,dt_rg,rf_rg]

for reg in regressors:
    reg.fit(x_train,y_train)
    pred = reg.predict(x_test)
    print("The Mean Squared Error score for", reg, "is", mean_squared_error(y_test,pred,squared=False))
    print("The R Squared Score for", reg, "is", r2_score(y_test,pred))
# Out:
# The Mean Squared Error score for LinearRegression() is 890477.5271779466
# The R Squared Score for LinearRegression() is 0.02350977226451023
# The Mean Squared Error score for Ridge() is 890389.031183617
# The R Squared Score for Ridge() is 0.023703850558499773
# c:\Users\Marcos Verdi\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.035e+15, tolerance: 1.082e+12
#   model = cd_fast.enet_coordinate_descent(
# The Mean Squared Error score for Lasso() is 890472.731573676
# The R Squared Score for Lasso() is 0.023520289875463507
# The Mean Squared Error score for DecisionTreeRegressor() is 741267.1643294233
# The R Squared Score for DecisionTreeRegressor() is 0.323338449629076
# The Mean Squared Error score for RandomForestRegressor() is 471801.486089378
# The R Squared Score for RandomForestRegressor() is 0.7258800884719249
